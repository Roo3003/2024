# %%
# Import class files

import sys
import os
parent_dir = os.path.abspath(os.path.join(os.getcwd(), os.pardir))
sys.path.append(parent_dir)

# %%
from queue import PriorityQueue
import math

example = open('example.txt', 'r').read()
puzzle = open('puzzle.txt', 'r').read()

input = puzzle

# %% [markdown]
# # Part 1

# %%
init_wires_info, logic_info = input.split('\n\n')

# Store name-to-wireval in a dictionary
wires = {}

remaining_wires = set()
z_wires = set()



# Initialise the starting wire values
for wire in init_wires_info.split('\n'):
    wires[wire[:3]] = int(wire[-1])


# Initialise needed logic
for logic in logic_info.split('\n'):
    wire1, gate, wire2, _, wire_out = logic.split(' ')

    # Append output wires to set
    if wire_out[0] == 'z':
        z_wires.add(wire_out)

    # Append wires to dict
    if wire_out not in wires:
        wires[wire_out] = wire1+gate+wire2
        remaining_wires.add(wire_out)

num_z_wires = len(z_wires)


# Iterate until we find all the z wire values
while(z_wires):

    # Iterate through all remaining wires to find, and find their value if we can
    to_remove = set()
    for wire in remaining_wires:
        logic_str = wires[wire]
        gate1, gate2, logic = logic_str[:3], logic_str[-3:], logic_str[3:-3]
        gate1_val, gate2_val = wires[gate1], wires[gate2]
        if gate1_val in [0,1] and gate2_val in [0,1]:
            match logic:
                case 'AND': val =  gate1_val and gate2_val
                case 'OR': val = gate1_val or gate2_val
                case 'XOR': val = gate1_val ^ gate2_val
            wires[wire] = val
            to_remove.add(wire)

            if wire[0] == 'z':
                z_wires.remove(wire)

    remaining_wires = remaining_wires - to_remove

def extract_z_wires(wires):
    '''
    Extracts the z wires from the wires dictionary and returns the binary number in decimal
    '''
    z_wires = []
    for wire in wires:
        if wire[0] == 'z':
            z_wires.append(wire)
    
    z_wires = sorted(z_wires, reverse=True)

    bin_str = ''
    for z_wire in z_wires:
        bin_str += str(wires[z_wire])
    
    return int(bin_str,2)

extract_z_wires(wires)
# Out:
# 55544677167336

# %% [markdown]
# # Part 2

# %%
def get_num(letter, wires):
    '''
    Returns the number from binary of the variables given by [letter]00, [letter]01, ...
    '''
    letter_wires = []
    for wire in wires:
        if wire[0] == letter:
            letter_wires.append(wire)
    
    letter_wires = sorted(letter_wires, reverse=True)

    bin_str = ''
    for letter_wire in letter_wires:
        bin_str += str(wires[letter_wire])
    
    return int(bin_str,2), bin_str
    
def swap_wires(wires, wire1, wire2):
    '''
    Swaps the output in wires 1 and 2
    '''
    wires[wire1], wires[wire2] = wires[wire2], wires[wire1]
    return wires

def eval_wires(wires):
    '''
    Iterates through each of the wires until we find all of the z-wire values
    '''
    z_wires = set()
    remaining_wires = set()

    for wire in wires:
        if wire[0] == 'z':
            z_wires.add(wire)
        if not isinstance(wires[wire], int):
            remaining_wires.add(wire)

    while(z_wires):

        # Iterate through all remaining wires to find, and find their value if we can
        to_remove = set()
        for wire in remaining_wires:
            logic_str = wires[wire]
            gate1, gate2, logic = logic_str[:3], logic_str[-3:], logic_str[3:-3]
            gate1_val, gate2_val = wires[gate1], wires[gate2]
            if gate1_val in [0,1] and gate2_val in [0,1]:
                match logic:
                    case 'AND': val =  gate1_val and gate2_val
                    case 'OR': val = gate1_val or gate2_val
                    case 'XOR': val = gate1_val ^ gate2_val
                wires[wire] = val
                to_remove.add(wire)

                if wire[0] == 'z':
                    z_wires.remove(wire)

        remaining_wires = remaining_wires - to_remove
    
    return wires

def reset_wires():
    '''
    Resets wires to starting state and returns
    '''
    init_wires_info, logic_info = input.split('\n\n')

    # Store name-to-wireval in a dictionary
    wires = {}

    remaining_wires = set()
    z_wires = set()



    # Initialise the starting wire values
    for wire in init_wires_info.split('\n'):
        wires[wire[:3]] = int(wire[-1])


    # Initialise needed logic
    for logic in logic_info.split('\n'):
        wire1, gate, wire2, _, wire_out = logic.split(' ')

        # Append output wires to set
        if wire_out[0] == 'z':
            z_wires.add(wire_out)

        # Append wires to dict
        if wire_out not in wires:
            wires[wire_out] = wire1+gate+wire2
            remaining_wires.add(wire_out)
    return wires

# %%
# Going to try and go for a graph visualisation: Input all of the connections and we should hopefully see that most of it is consistent, but
# that some of it is not - wherever those happen, we should have a swapped gate!

# So to visualise this, we need a list of inputs into each gate, and gates leading into outputs

def generate_graph_code(wires, wires_to_swap=[]):
    '''Generates graphviz code given a set of wires to view the connections'''
    wires = reset_wires()
    if wires_to_swap:
        for swap in wires_to_swap:
            swap_wires(wires, swap[0], swap[1])

    connections = set()

    for wire in wires:
        logic = wires[wire]
        if not isinstance(wires[wire], int):
            in1, in2, gate, out = logic[:3], logic[-3:], logic[3:-3], wire
            for input_wire in [in1,in2]:
                connections.add((input_wire+' -> '+out, gate))


    con_str = ''

    for connection in connections:
        con_str += connection[0]+'; '

    x_str = ''
    y_str = ''
    z_str = ''

    for i in range(45):
        if i < 10:
            x_str += 'x0'+str(i)+' -> '
            y_str += 'y0'+str(i)+' -> '
            z_str += 'z0'+str(i)+' -> '
        else:
            x_str += 'x'+str(i)+' -> '
            y_str += 'y'+str(i)+' -> '
            z_str += 'z'+str(i)+' -> '

    z_str += 'z45'

    x_str = x_str[:-4]
    y_str = y_str[:-4]

    and_str = ''
    or_str = ''
    xor_str = ''

    for connection in connections:
        match connection[1]:
            case 'AND': and_str += connection[0][-3:]+'; '
            case 'OR': or_str += connection[0][-3:]+'; '
            case 'XOR': xor_str += connection[0][-3:]+'; '

    graphviz_code = f'''digraph G {{

    subgraph and_gate {{ 
        node[style=filled,color=orange];
        {and_str}
    }}

    subgraph or_gate {{
        node[style=filled, color=yellow];
        {or_str}
    }}

    subgraph xor_gate {{
        node[style=filled, color=green];
        {xor_str}
    }}

    {con_str}
    {x_str}
    {y_str}
    {z_str}
    }}
    '''

    return graphviz_code

print(generate_graph_code(wires))
# Out:
# digraph G {
#
#     subgraph and_gate {
#         node[style=filled,color=orange];
#         fph; cns; qgh; mdq; ssd; jtq; mfj; hsd; hwt; fhh; mfj; crb; qhw; jtq; mmm; bdj; mjb; psk; ctc; hnm; dvg; nng; thg; hkv; ftq; hwt; mck; ggw; qrs; pdt; skt; kmb; kmg; psk; fkw; bdj; dvg; fph; qmv; pbd; wfr; ggw; vkh; vth; kbg; fws; qmv; tct; qrs; mjb; nbj; pbd; mmm; fkw; drg; jhq; bjj; cnp; nsf; nvm; dbc; rbb; nkm; bvs; jhq; bjf; skj; rcn; ftq; mjs; hjd; hkv; gfv; cnp; qcb; skj; cns; bvs; tct; vkh; nhq; z32; frm; gfv; mdq; qtn; nvm; tbc; crb; vdn; knt; nkm; z26; rjj; hjf; ssd; rcn; bjf; nsf; hgk; rkn; hgk; cbq; psw; psw; tbc; nhq; vqk; mck; dgn; rgv; jvv; fhh; bbb; drg; gpv; hjf; ctc; pdt; hnm; khd; rnw; qhw; gth; hjd; z32; gwd; qcb; cbq; qnf; vdn; rgv; fws; rkn; qtn; khd; gpv; thg; gth; rbb; tkm; nbj; rnw; kbg; mtd; nng; gwd; mtd; frm; qsm; dbc; z26; wbb; qnf; dcc; vqk; bjj; bdr; jvv; vth; qsm; dcc; skt; rjj; bdr; bdg; qgh; bbb; kmg; hsd; mjs; kmb; bdg; wbb; tkm; knt; wfr; dgn;
#     }
#
#     subgraph or_gate {
#         node[style=filled, color=yellow];
#         mdd; nvq; wfg; sqb; wfg; str; rhr; pbt; crt; kqs; mbg; bpc; tnr; hhd; dtj; pbt; gjg; vbp; dft; kqs; dtj; fhb; mwg; cmf; msm; twj; nwm; jnj; spq; crt; vtg; mwg; pmm; qjv; tnr; brg; whc; vtg; dpg; rpt; wkk; gvs; ksf; rjb; htb; ghk; twj; ttv; rtk; ths; mdd; ghk; cdq; fhb; dpg; nwm; sqb; z12; mbg; vbp; rjb; msm; ksf; nvq; rpt; gjg; spq; cmf; dft; wkk; hhd; z12; rhr; brg; ttv; z45; cdq; str; qjv; gvs; whc; ths; jnj; bpc; rtk; z45; pmm; htb;
#     }
#
#     subgraph xor_gate {
#         node[style=filled, color=green];
#         z28; gsd; tmj; tbt; gtt; rsk; gtt; kdw; z43; z41; gnj; qbp; ckk; msc; z08; bkh; z05; z31; kdw; ndh; z19; fht; z37; bhh; z33; fnm; swt; kqc; mtp; vwf; z25; ndh; dfp; gtd; z18; hpp; z06; pbj; z25; trd; jkb; dfp; jvg; rsk; vhk; z23; gnj; jrg; trd; z20; z14; z17; swt; z19; z10; nnt; z27; z02; qnv; z29; jfr; z04; z30; z36; kth; phr; vpm; z05; qdt; tbt; z21; z04; z20; z16; phr; nkr; tmj; z06; qdt; z16; z34; pts; z41; z34; jfr; z30; jkb; fnm; jvg; rpb; spr; z44; nhb; z24; gtd; wnd; z09; z27; z14; mtp; jng; z22; z28; hsq; z35; vpm; z31; z35; z18; z15; rpb; hbh; nhb; pbj; z21; z22; z10; z29; kqc; jrg; z15; jng; z17; z39; msc; z01; z07; z36; bhh; z09; z39; ttt; qnv; z13; z08; qbp; spr; hsq; z11; z38; gsd; z42; z33; ttt; z44; z40; z01; z00; z00; z24; pgc; z42; z37; z03; twd; twd; z40; nnt; z11; bkh; ckk; z38; z23; fht; hpp; z13; nkr; z43; z03; pgc; z07; z02; vhk; wnd; hbh; pts; vwf; kth;
#     }
#
#     x02 -> fph; kth -> cns; vhk -> qgh; x11 -> mdq; kqc -> ssd; y33 -> jtq; pgc -> z28; vwf -> mfj; rgv -> mdd; dfp -> gsd; wbb -> nvq; y23 -> tmj; frm -> wfg; vtg -> tbt; x05 -> gtt; ctc -> sqb; y43 -> hsd; x02 -> rsk; psk -> wfg; hwt -> str; cbq -> rhr; tct -> pbt; x04 -> hwt; y40 -> fhh; y05 -> gtt; y11 -> kdw; hgk -> crt; dpg -> z43; qsm -> kqs; jkb -> z41; dft -> mfj; qmv -> mbg; x28 -> crb; x43 -> gnj; y24 -> qbp; ghk -> qhw; x15 -> ckk; x33 -> jtq; x25 -> msc; pts -> mmm; y00 -> bdj; whc -> z08; rbb -> bpc; y32 -> bkh; gtt -> z05; x10 -> mjb; dtj -> z31; x11 -> kdw; y08 -> ndh; knt -> tnr; jvg -> z19; gvs -> psk; rpt -> ctc; y29 -> fht; wkk -> z37; wnd -> hnm; bdg -> hhd; x34 -> bhh; gjg -> dvg; cdq -> nng; htb -> thg; mck -> dtj; bdr -> pbt; nwm -> z33; ttt -> hkv; qgh -> gjg; msc -> ftq; x10 -> fnm; crb -> vbp; y27 -> swt; nbj -> dft; rjj -> kqs; x22 -> kqc; y13 -> mtp; y04 -> vwf; y04 -> hwt; rkn -> dtj; nvq -> mck; msc -> z25; x37 -> ggw; x08 -> ndh; y26 -> dfp; x13 -> qrs; y30 -> gtd; mdd -> pdt; y32 -> skt; mmm -> fhb; pbj -> z18; rpb -> kmb; y37 -> hpp; rjb -> z06; y38 -> kmg; x18 -> pbj; tmj -> psk; mjs -> mwg; kbg -> cmf; tnr -> fkw; pmm -> z25; x00 -> bdj; nkr -> dvg; y31 -> trd; y02 -> fph; x41 -> jkb; x25 -> qmv; x18 -> pbd; pbj -> wfr; jhq -> msm; y37 -> ggw; x26 -> dfp; x34 -> vkh; nkm -> twj; skt -> nwm; y05 -> vth; y19 -> jvg; mbg -> kbg; y02 -> rsk; nsf -> jnj; y20 -> vhk; wfg -> fws; y25 -> qmv; gvs -> z23; y43 -> gnj; hhd -> tct; y13 -> qrs; y10 -> mjb; wfr -> spq; gfv -> crt; bjf -> vtg; jfr -> nbj; dbc -> mwg; y06 -> jrg; y18 -> pbd; x31 -> trd; qcb -> pmm; crt -> z20; qjv -> mmm; kdw -> fkw; bjj -> qjv; mjb -> tnr; rpt -> z14; x29 -> drg; qjv -> z17; x15 -> jhq; qdt -> bjj; dcc -> brg; x27 -> swt; spq -> z19; hnm -> whc; x35 -> cnp; kqs -> z10; dpg -> nsf; nhq -> vtg; swt -> nvm; y44 -> nnt; swt -> z27; rsk -> z02; y39 -> qnv; fht -> z29; rcn -> dpg; x06 -> dbc; whc -> rbb; x03 -> jfr; rsk -> nkm; jkb -> bvs; y15 -> jhq; qrs -> rpt; vwf -> z04; gtd -> z30; trd -> bjf; y14 -> skj; htb -> z36; nhb -> kth; y38 -> phr; x36 -> vpm; str -> z05; x42 -> rcn; y16 -> qdt; bkh -> tbt; pmm -> ftq; jrg -> mjs; gjg -> z21; dft -> z04; x16 -> hjd; vpm -> wkk; pbt -> hkv; jvg -> gfv; y35 -> cnp; ssd -> gvs; x24 -> qcb; x14 -> skj; mtp -> cns; ttv -> bvs; vhk -> z20; qdt -> z16; x38 -> phr; qnv -> tct; x21 -> nkr; x23 -> tmj; jrg -> z06; y34 -> vkh; kmb -> ksf; y31 -> nhq; bkh -> z32; x16 -> qdt; vth -> rjb; x23 -> frm; spq -> gfv; y11 -> mdq; cnp -> htb; msm -> z16; ksf -> z34; nnt -> qtn; x17 -> pts; cmf -> nvm; x27 -> tbc; ttv -> z41; y28 -> crb; x44 -> vdn; bhh -> z34; kqs -> knt; y03 -> jfr; rhr -> nkm; tbc -> ghk; nvq -> z30; fph -> twj; y41 -> jkb; x26 -> z26; hkv -> ttv; hsq -> rjj; x22 -> hjf; rtk -> ssd; y10 -> fnm; y42 -> rcn; dtj -> bjf; x19 -> jvg; gnj -> nsf; dvg -> rtk; x19 -> hgk; x33 -> rpb; x30 -> rkn; y19 -> hgk; bdj -> cbq; x42 -> spr; jnj -> z44; x12 -> nhb; qbp -> z24; x12 -> psw; x30 -> gtd; gpv -> ths; bvs -> mdd; x07 -> wnd; y12 -> psw; bpc -> z09; nvm -> ghk; cmf -> z27; hbh -> z14; y27 -> tbc; x13 -> mtp; x35 -> jng; fkw -> cdq; kqc -> z22; x31 -> nhq; y07 -> vqk; gtd -> mck; sqb -> dgn; ghk -> z28; x09 -> hsq; y41 -> rgv; jng -> z35; str -> jvv; x40 -> fhh; tkm -> fhb; brg -> bbb; y36 -> vpm; trd -> z31; brg -> z35; pdt -> dpg; y29 -> drg; hpp -> gpv; tbt -> nwm; fhb -> z18; y22 -> hjf; sqb -> z15; skj -> sqb; hbh -> ctc; spr -> pdt; mwg -> hnm; y20 -> khd; y33 -> rpb; x14 -> hbh; psw -> z12; x03 -> rnw; pgc -> qhw; y12 -> nhb; ftq -> mbg; y18 -> pbj; y08 -> gth; y16 -> hjd; vtg -> z32; nkr -> z21; rtk -> z22; y01 -> gwd; fnm -> z10; vbp -> z29; y22 -> kqc; x06 -> jrg; ckk -> z15; y35 -> jng; qhw -> vbp; jvv -> rjb; dgn -> msm; y24 -> qcb; twd -> cbq; y36 -> qnf; pts -> z17; y44 -> vdn; x41 -> rgv; qnv -> z39; jtq -> ksf; qbp -> fws; y30 -> rkn; y25 -> msc; jnj -> qtn; drg -> nvq; x20 -> khd; wkk -> gpv; qnf -> thg; bdj -> z01; cns -> rpt; x08 -> gth; mwg -> z07; ndh -> rbb; qnf -> z36;  ...
#     x00 -> x01 -> x02 -> x03 -> x04 -> x05 -> x06 -> x07 -> x08 -> x09 -> x10 -> x11 -> x12 -> x13 -> x14 -> x15 -> x16 -> x17 -> x18 -> x19 -> x20 -> x21 -> x22 -> x23 -> x24 -> x25 -> x26 -> x27 -> x28 -> x29 -> x30 -> x31 -> x32 -> x33 -> x34 -> x35 -> x36 -> x37 -> x38 -> x39 -> x40 -> x41 -> x42 -> x43 -> x44
#     y00 -> y01 -> y02 -> y03 -> y04 -> y05 -> y06 -> y07 -> y08 -> y09 -> y10 -> y11 -> y12 -> y13 -> y14 -> y15 -> y16 -> y17 -> y18 -> y19 -> y20 -> y21 -> y22 -> y23 -> y24 -> y25 -> y26 -> y27 -> y28 -> y29 -> y30 -> y31 -> y32 -> y33 -> y34 -> y35 -> y36 -> y37 -> y38 -> y39 -> y40 -> y41 -> y42 -> y43 -> y44
#     z00 -> z01 -> z02 -> z03 -> z04 -> z05 -> z06 -> z07 -> z08 -> z09 -> z10 -> z11 -> z12 -> z13 -> z14 -> z15 -> z16 -> z17 -> z18 -> z19 -> z20 -> z21 -> z22 -> z23 -> z24 -> z25 -> z26 -> z27 -> z28 -> z29 -> z30 -> z31 -> z32 -> z33 -> z34 -> z35 -> z36 -> z37 -> z38 -> z39 -> z40 -> z41 -> z42 -> z43 -> z44 -> z45
#     }

# %%
# Rules...

# - z gates are XOR
# - z gates have 1 XOR and 1 OR feeding into them
# - x and y gates feed into 1 AND and 1 XOR

# Swap z12 - kth
# Swap z26 - gsd
# Swap z32 - tbt
# Swap qnf - vpm


bad_gates = set(['z12','z26','z32','kth','gsd','qnf','vpm','tbt'])

# %%
print(generate_graph_code(wires, wires_to_swap=[['z12','kth'], ['z26','gsd'],['z32','tbt'], ['qnf','vpm']]))
# Out:
# digraph G {
#
#     subgraph and_gate {
#         node[style=filled,color=orange];
#         fph; cns; qgh; ssd; mdq; jtq; mfj; gsd; hsd; hwt; fhh; mfj; crb; qhw; jtq; mmm; bdj; mjb; psk; ctc; hnm; dvg; nng; thg; hkv; ftq; hwt; mck; ggw; qrs; pdt; skt; kmb; kmg; psk; fkw; bdj; dvg; fph; qmv; pbd; wfr; ggw; vkh; vth; kbg; fws; qmv; tct; qrs; mjb; nbj; pbd; mmm; fkw; drg; jhq; bjj; cnp; nsf; tbt; nvm; dbc; rbb; nkm; bvs; jhq; bjf; skj; rcn; ftq; mjs; hjd; hkv; gfv; cnp; qcb; skj; cns; bvs; tct; vkh; nhq; frm; gfv; mdq; qtn; nvm; tbc; crb; vdn; knt; nkm; rjj; hjf; ssd; rcn; bjf; nsf; hgk; rkn; hgk; cbq; psw; psw; tbc; nhq; vqk; mck; dgn; rgv; jvv; fhh; bbb; drg; gpv; hjf; ctc; pdt; hnm; khd; rnw; qhw; gth; hjd; gwd; qcb; cbq; vdn; rgv; fws; rkn; qtn; khd; gpv; thg; gth; rbb; vpm; tbt; tkm; nbj; rnw; kbg; mtd; nng; gwd; mtd; frm; qsm; dbc; wbb; dcc; vqk; bjj; bdr; jvv; vth; qsm; dcc; skt; rjj; bdr; bdg; qgh; bbb; kmg; hsd; mjs; kmb; bdg; wbb; tkm; vpm; knt; gsd; wfr; dgn;
#     }
#
#     subgraph or_gate {
#         node[style=filled, color=yellow];
#         kth; mdd; nvq; wfg; sqb; wfg; str; rhr; pbt; crt; kqs; mbg; bpc; tnr; hhd; dtj; pbt; gjg; vbp; dft; kqs; dtj; fhb; mwg; cmf; msm; twj; nwm; jnj; spq; crt; vtg; mwg; pmm; qjv; tnr; brg; whc; vtg; dpg; rpt; wkk; gvs; kth; ksf; rjb; htb; ghk; twj; ttv; rtk; ths; mdd; ghk; cdq; fhb; dpg; nwm; sqb; mbg; vbp; rjb; msm; ksf; nvq; rpt; gjg; spq; cmf; dft; wkk; hhd; rhr; brg; ttv; z45; cdq; str; qjv; gvs; whc; ths; jnj; bpc; rtk; z45; pmm; htb;
#     }
#
#     subgraph xor_gate {
#         node[style=filled, color=green];
#         z28; tmj; gtt; rsk; gtt; kdw; z43; z41; gnj; qbp; ckk; msc; z08; bkh; z05; z31; kdw; ndh; z19; fht; z37; bhh; z33; fnm; swt; kqc; mtp; vwf; z25; z32; ndh; dfp; gtd; z18; hpp; z06; pbj; z25; trd; jkb; dfp; jvg; rsk; vhk; z23; gnj; jrg; trd; z20; z14; z17; swt; z19; z10; z32; nnt; z27; z02; qnv; z29; qnf; jfr; z04; z30; z36; phr; z05; qdt; z21; z04; z12; z20; z16; phr; nkr; tmj; z06; qnf; qdt; z16; z34; pts; z41; z34; jfr; z30; jkb; fnm; jvg; rpb; spr; z44; nhb; z26; z24; gtd; wnd; z09; z27; z14; mtp; jng; z22; z28; hsq; z35; z31; z35; z12; z18; z15; rpb; hbh; nhb; pbj; z21; z22; z10; z29; kqc; jrg; z15; jng; z17; z39; msc; z01; z07; z36; bhh; z09; z39; ttt; qnv; z26; z13; z08; qbp; spr; hsq; z11; z38; z42; z33; ttt; z44; z40; z01; z00; z00; z24; pgc; z42; z37; z03; twd; twd; z40; nnt; z11; bkh; ckk; z38; z23; fht; hpp; z13; nkr; z43; z03; pgc; z07; z02; vhk; wnd; hbh; pts; vwf;
#     }
#
#     x02 -> fph; kth -> cns; vhk -> qgh; psw -> kth; kqc -> ssd; x11 -> mdq; y33 -> jtq; pgc -> z28; vwf -> mfj; rgv -> mdd; wbb -> nvq; y23 -> tmj; y26 -> gsd; frm -> wfg; x05 -> gtt; ctc -> sqb; y43 -> hsd; x02 -> rsk; psk -> wfg; hwt -> str; cbq -> rhr; tct -> pbt; x04 -> hwt; y40 -> fhh; y05 -> gtt; y11 -> kdw; hgk -> crt; dpg -> z43; qsm -> kqs; jkb -> z41; dft -> mfj; qmv -> mbg; x28 -> crb; x43 -> gnj; y24 -> qbp; ghk -> qhw; x15 -> ckk; x33 -> jtq; x25 -> msc; pts -> mmm; y00 -> bdj; whc -> z08; rbb -> bpc; y32 -> bkh; gtt -> z05; x10 -> mjb; dtj -> z31; x11 -> kdw; y08 -> ndh; knt -> tnr; jvg -> z19; gvs -> psk; rpt -> ctc; y29 -> fht; wkk -> z37; wnd -> hnm; bdg -> hhd; x34 -> bhh; gjg -> dvg; cdq -> nng; htb -> thg; mck -> dtj; bdr -> pbt; nwm -> z33; ttt -> hkv; qgh -> gjg; msc -> ftq; x10 -> fnm; crb -> vbp; y27 -> swt; nbj -> dft; rjj -> kqs; x22 -> kqc; y13 -> mtp; y04 -> vwf; y04 -> hwt; rkn -> dtj; nvq -> mck; msc -> z25; x37 -> ggw; bkh -> z32; x08 -> ndh; y26 -> dfp; x13 -> qrs; y30 -> gtd; mdd -> pdt; y32 -> skt; mmm -> fhb; pbj -> z18; rpb -> kmb; y37 -> hpp; rjb -> z06; y38 -> kmg; x18 -> pbj; tmj -> psk; mjs -> mwg; kbg -> cmf; tnr -> fkw; pmm -> z25; x00 -> bdj; nkr -> dvg; y31 -> trd; y02 -> fph; x41 -> jkb; x25 -> qmv; x18 -> pbd; pbj -> wfr; jhq -> msm; y37 -> ggw; x26 -> dfp; x34 -> vkh; nkm -> twj; skt -> nwm; y05 -> vth; y19 -> jvg; mbg -> kbg; y02 -> rsk; nsf -> jnj; y20 -> vhk; wfg -> fws; y25 -> qmv; gvs -> z23; y43 -> gnj; hhd -> tct; y13 -> qrs; y10 -> mjb; wfr -> spq; gfv -> crt; bjf -> vtg; jfr -> nbj; dbc -> mwg; y06 -> jrg; y18 -> pbd; x31 -> trd; qcb -> pmm; crt -> z20; qjv -> mmm; kdw -> fkw; bjj -> qjv; mjb -> tnr; rpt -> z14; x29 -> drg; qjv -> z17; x15 -> jhq; qdt -> bjj; dcc -> brg; x27 -> swt; spq -> z19; hnm -> whc; x35 -> cnp; kqs -> z10; dpg -> nsf; vtg -> z32; vtg -> tbt; nhq -> vtg; swt -> nvm; y44 -> nnt; swt -> z27; rsk -> z02; y39 -> qnv; fht -> z29; rcn -> dpg; y36 -> qnf; x06 -> dbc; whc -> rbb; x03 -> jfr; rsk -> nkm; jkb -> bvs; y15 -> jhq; qrs -> rpt; vwf -> z04; gtd -> z30; trd -> bjf; y14 -> skj; htb -> z36; y38 -> phr; str -> z05; x42 -> rcn; y16 -> qdt; pmm -> ftq; jrg -> mjs; gjg -> z21; dft -> z04; x16 -> hjd; vpm -> wkk; pbt -> hkv; nhb -> z12; jvg -> gfv; y35 -> cnp; ssd -> gvs; x24 -> qcb; x14 -> skj; mtp -> cns; ttv -> bvs; vhk -> z20; qdt -> z16; x38 -> phr; qnv -> tct; x21 -> nkr; x23 -> tmj; jrg -> z06; nng -> kth; y34 -> vkh; kmb -> ksf; y31 -> nhq; x36 -> qnf; x16 -> qdt; vth -> rjb; x23 -> frm; spq -> gfv; y11 -> mdq; cnp -> htb; msm -> z16; ksf -> z34; nnt -> qtn; x17 -> pts; cmf -> nvm; x27 -> tbc; ttv -> z41; y28 -> crb; x44 -> vdn; bhh -> z34; kqs -> knt; y03 -> jfr; rhr -> nkm; tbc -> ghk; nvq -> z30; fph -> twj; y41 -> jkb; hkv -> ttv; hsq -> rjj; x22 -> hjf; rtk -> ssd; y10 -> fnm; y42 -> rcn; dtj -> bjf; x19 -> jvg; gnj -> nsf; dvg -> rtk; x19 -> hgk; x33 -> rpb; x30 -> rkn; y19 -> hgk; bdj -> cbq; x42 -> spr; jnj -> z44; x12 -> nhb; mbg -> z26; qbp -> z24; x12 -> psw; x30 -> gtd; gpv -> ths; bvs -> mdd; x07 -> wnd; y12 -> psw; bpc -> z09; nvm -> ghk; cmf -> z27; hbh -> z14; y27 -> tbc; x13 -> mtp; x35 -> jng; fkw -> cdq; kqc -> z22; x31 -> nhq; y07 -> vqk; gtd -> mck; sqb -> dgn; ghk -> z28; x09 -> hsq; y41 -> rgv; jng -> z35; str -> jvv; x40 -> fhh; tkm -> fhb; brg -> bbb; trd -> z31; brg -> z35; pdt -> dpg; y29 -> drg; hpp -> gpv; tbt -> nwm; cdq -> z12; fhb -> z18; y22 -> hjf; sqb -> z15; skj -> sqb; hbh -> ctc; spr -> pdt; mwg -> hnm; y20 -> khd; y33 -> rpb; x14 -> hbh; x03 -> rnw; pgc -> qhw; y12 -> nhb; ftq -> mbg; y18 -> pbj; y08 -> gth; y16 -> hjd; nkr -> z21; rtk -> z22; y01 -> gwd; fnm -> z10; vbp -> z29; y22 -> kqc; x06 -> jrg; ckk -> z15; y35 -> jng; qhw -> vbp; jvv -> rjb; dgn -> msm; y24 -> qcb; twd -> cbq; pts -> z17; y44 -> vdn; x41 -> rgv; qnv -> z39; jtq -> ksf; qbp -> fws; y30 -> rkn; y25 -> msc; jnj -> qtn; drg -> nvq; x20 -> khd; wkk -> gpv; qnf -> thg; bdj -> z01; cns -> rpt; x08 -> gth; mwg -> z07; ndh -> rbb; qnf -> z36;  ...
#     x00 -> x01 -> x02 -> x03 -> x04 -> x05 -> x06 -> x07 -> x08 -> x09 -> x10 -> x11 -> x12 -> x13 -> x14 -> x15 -> x16 -> x17 -> x18 -> x19 -> x20 -> x21 -> x22 -> x23 -> x24 -> x25 -> x26 -> x27 -> x28 -> x29 -> x30 -> x31 -> x32 -> x33 -> x34 -> x35 -> x36 -> x37 -> x38 -> x39 -> x40 -> x41 -> x42 -> x43 -> x44
#     y00 -> y01 -> y02 -> y03 -> y04 -> y05 -> y06 -> y07 -> y08 -> y09 -> y10 -> y11 -> y12 -> y13 -> y14 -> y15 -> y16 -> y17 -> y18 -> y19 -> y20 -> y21 -> y22 -> y23 -> y24 -> y25 -> y26 -> y27 -> y28 -> y29 -> y30 -> y31 -> y32 -> y33 -> y34 -> y35 -> y36 -> y37 -> y38 -> y39 -> y40 -> y41 -> y42 -> y43 -> y44
#     z00 -> z01 -> z02 -> z03 -> z04 -> z05 -> z06 -> z07 -> z08 -> z09 -> z10 -> z11 -> z12 -> z13 -> z14 -> z15 -> z16 -> z17 -> z18 -> z19 -> z20 -> z21 -> z22 -> z23 -> z24 -> z25 -> z26 -> z27 -> z28 -> z29 -> z30 -> z31 -> z32 -> z33 -> z34 -> z35 -> z36 -> z37 -> z38 -> z39 -> z40 -> z41 -> z42 -> z43 -> z44 -> z45
#     }

# %%
wire_keys = list(wires.keys())
wire_keys

orig_wires = reset_wires()
x_num = get_num('x', wires)
y_num = get_num('y', wires)
target = x_num[0] + y_num[0]

x_num, y_num, target
# Out:
# ((33884112699961, '111101101000101000010100000000100001000111001'),
#  (21587482918575, '100111010001000111010010000000011111010101111'),
#  55471595618536)

# %%
bad_gates = list(bad_gates)
','.join(sorted(bad_gates))
# Out:
# 'gsd,kth,qnf,tbt,vpm,z12,z26,z32'
